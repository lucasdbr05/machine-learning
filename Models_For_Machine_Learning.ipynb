# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib

# %%
x = 2*np.random.rand(100, 1)
y= 4 + 3*x + np.random.randn(100, 1)

# %% [markdown]
# ## Linear Regression model

# %%
fig, ax = plt.subplots(figsize=(20, 8))
plt.scatter(x, y)

# %%
X = np.c_[np.ones((100, 1)), x]
X
# Out:
# array([[1.        , 1.07684976],
#        [1.        , 1.71771144],
#        [1.        , 1.87783696],
#        [1.        , 1.65308834],
#        [1.        , 0.29025256],
#        [1.        , 1.46522078],
#        [1.        , 1.13428149],
#        [1.        , 0.75514564],
#        [1.        , 1.06309299],
#        [1.        , 1.98066529],
#        [1.        , 1.84730082],
#        [1.        , 0.07615406],
#        [1.        , 1.15324873],
#        [1.        , 0.78863735],
#        [1.        , 0.44191077],
#        [1.        , 1.18275276],
#        [1.        , 0.95771873],
#        [1.        , 0.2173401 ],
#        [1.        , 1.19616315],
#        [1.        , 1.25508237],
#        [1.        , 1.56262343],
#        [1.        , 1.2916907 ],
#        [1.        , 0.51251366],
#        [1.        , 1.24919374],
#        [1.        , 0.22380408],
#        [1.        , 0.29131891],
#        [1.        , 0.52964179],
#        [1.        , 0.31554789],
#        [1.        , 0.54257914],
#        [1.        , 1.87932451],
#        [1.        , 0.93784403],
#        [1.        , 0.78264153],
#        [1.        , 1.60005136],
#        [1.        , 0.40457385],
#        [1.        , 0.0457592 ],
#        [1.        , 1.2297215 ],
#        [1.        , 1.26406034],
#        [1.        , 0.04826551],
#        [1.        , 0.62517429],
#        [1.        , 1.35847299],
#        [1.        , 1.67666774],
#        [1.        , 0.37254315],
#        [1.        , 1.15552226],
#        [1.        , 0.68033876],
#        [1.        , 0.93544733],
#        [1.        , 0.86087309],
#        [1.        , 0.31630735],
#        [1.        , 1.25486246],
#        [1.        , 0.35501871],
#        [1.        , 0.98760441],
#        [1.        , 0.81511139],
#        [1.        , 0.26878219],
#        [1.        , 0.03982519],
#        [1.        , 0.83713403],
#        [1.        , 0.61355894],
#        [1.        , 0.86033645],
#        [1.        , 1.58966487],
#        [1.        , 0.02999659],
#        [1.        , 0.79975856],
#        [1.        , 1.70213668],
#        [1.        , 1.77432722],
#        [1.        , 1.69576532],
#        [1.        , 0.15820436],
#        [1.        , 1.16797824],
#        [1.        , 0.19963195],
#        [1.        , 0.31271124],
#        [1.        , 1.6316469 ],
#        [1.        , 1.62063802],
#        [1.        , 0.715154  ],
#        [1.        , 1.54251446],
#        [1.        , 0.52227379],
#        [1.        , 1.18748679],
#        [1.        , 1.08842929],
#        [1.        , 1.68062342],
#        [1.        , 1.22885149],
#        [1.        , 0.14305571],
#        [1.        , 0.19431949],
#        [1.        , 1.98569484],
#        [1.        , 1.17976069],
#        [1.        , 0.66831829],
#        [1.        , 0.15001037],
#        [1.        , 0.47282987],
#        [1.        , 1.91903515],
#        [1.        , 1.24223747],
#        [1.        , 0.06403694],
#        [1.        , 0.21812137],
#        [1.        , 1.72640761],
#        [1.        , 1.63051951],
#        [1.        , 1.67341933],
#        [1.        , 1.81947061],
#        [1.        , 1.25808938],
#        [1.        , 0.44016402],
#        [1.        , 1.5446611 ],
#        [1.        , 1.89237399],
#        [1.        , 0.51757612],
#        [1.        , 0.53078057],
#        [1.        , 1.58695303],
#        [1.        , 0.81798627],
#        [1.        , 1.73027485],
#        [1.        , 1.2441068 ]])

# %%
theta = np.linalg.inv(X.T.dot(X)).dot(X.T).dot(y)
theta
# Out:
# array([[3.99722398],
#        [3.03718454]])

# %%
y_hat = theta[1]*X + theta[0]
y_hat
# Out:
# array([[ 7.03440852,  7.26781543],
#        [ 7.03440852,  9.21423061],
#        [ 7.03440852,  9.70056135],
#        [ 7.03440852,  9.01795834],
#        [ 7.03440852,  4.87877458],
#        [ 7.03440852,  8.44736987],
#        [ 7.03440852,  7.44224618],
#        [ 7.03440852,  6.29074064],
#        [ 7.03440852,  7.22603358],
#        [ 7.03440852, 10.01286997],
#        [ 7.03440852,  9.60781749],
#        [ 7.03440852,  4.2285179 ],
#        [ 7.03440852,  7.49985321],
#        [ 7.03440852,  6.39246116],
#        [ 7.03440852,  5.33938855],
#        [ 7.03440852,  7.58946239],
#        [ 7.03440852,  6.90599251],
#        [ 7.03440852,  4.65732597],
#        [ 7.03440852,  7.63019221],
#        [ 7.03440852,  7.80914076],
#        [ 7.03440852,  8.7431997 ],
#        [ 7.03440852,  7.920327  ],
#        [ 7.03440852,  5.55382254],
#        [ 7.03440852,  7.79125591],
#        [ 7.03440852,  4.67695828],
#        [ 7.03440852,  4.88201328],
#        [ 7.03440852,  5.60584385],
#        [ 7.03440852,  4.95560115],
#        [ 7.03440852,  5.64513695],
#        [ 7.03440852,  9.70507934],
#        [ 7.03440852,  6.84562937],
#        [ 7.03440852,  6.37425073],
#        [ 7.03440852,  8.85687523],
#        [ 7.03440852,  5.22598943],
#        [ 7.03440852,  4.13620313],
#        [ 7.03440852,  7.7321151 ],
#        [ 7.03440852,  7.8364085 ],
#        [ 7.03440852,  4.14381525],
#        [ 7.03440852,  5.89599366],
#        [ 7.03440852,  8.12315714],
#        [ 7.03440852,  9.08957332],
#        [ 7.03440852,  5.12870628],
#        [ 7.03440852,  7.50675834],
#        [ 7.03440852,  6.06353833],
#        [ 7.03440852,  6.83835016],
#        [ 7.03440852,  6.61185444],
#        [ 7.03440852,  4.95790778],
#        [ 7.03440852,  7.80847285],
#        [ 7.03440852,  5.07548131],
#        [ 7.03440852,  6.99676082],
#        [ 7.03440852,  6.47286769],
#        [ 7.03440852,  4.8135651 ],
#        [ 7.03440852,  4.11818045],
#        [ 7.03440852,  6.53975453],
#        [ 7.03440852,  5.8607157 ],
#        [ 7.03440852,  6.61022456],
#        [ 7.03440852,  8.82532955],
#        [ 7.03440852,  4.08832916],
#        [ 7.03440852,  6.42623832],
#        [ 7.03440852,  9.16692718],
#        [ 7.03440852,  9.38618318],
#        [ 7.03440852,  9.14757619],
#        [ 7.03440852,  4.47771983],
#        [ 7.03440852,  7.54458945],
#        [ 7.03440852,  4.60354307],
#        [ 7.03440852,  4.94698574],
#        [ 7.03440852,  8.95283672],
#        [ 7.03440852,  8.91940072],
#        [ 7.03440852,  6.16927867],
#        [ 7.03440852,  8.68212506],
#        [ 7.03440852,  5.58346585],
#        [ 7.03440852,  7.60384051],
#        [ 7.03440852,  7.30298461],
#        [ 7.03440852,  9.10158745],
#        [ 7.03440852,  7.72947273],
#        [ 7.03440852,  4.43171059],
#        [ 7.03440852,  4.58740814],
#        [ 7.03440852, 10.02814567],
#        [ 7.03440852,  7.5803749 ],
#        [ 7.03440852,  6.02702995],
#        [ 7.03440852,  4.45283316],
#        [ 7.03440852,  5.43329556],
#        [ 7.03440852,  9.82568789],
#        [ 7.03440852,  7.77012844],
#        [ 7.03440852,  4.19171599],
#        [ 7.03440852,  4.65969885],
#        [ 7.03440852,  9.24064249],
#        [ 7.03440852,  8.94941263],
#        [ 7.03440852,  9.07970729],
#        [ 7.03440852,  9.523292  ],
#        [ 7.03440852,  7.81827359],
#        [ 7.03440852,  5.33408333],
#        [ 7.03440852,  8.6886448 ],
#        [ 7.03440852,  9.744713  ],
#        [ 7.03440852,  5.56919818],
#        [ 7.03440852,  5.60930251],
#        [ 7.03440852,  8.81709318],
#        [ 7.03440852,  6.48159923],
#        [ 7.03440852,  9.25238799],
#        [ 7.03440852,  7.77580592]])

# %%
fig, ax = plt.subplots(figsize=(20, 8))
plt.plot(x, y_hat)
plt.scatter(x, y)

# %% [markdown]
# ## Gradient Descendent

# %%
eta = 0.01
epochs = 101
m = 100

theta = np.random.randn(2, 1)

fig, ax = plt.subplots(figsize=(20, 8))
plt.scatter(x, y)

for i in range(epochs):
    gradients = 2 * X.T.dot(X.dot(theta) - y) / m 
    theta -= (gradients * eta)

    y_hat = theta[1]*x + theta[0]

    if(i%10 == 0):
        ax.plot(x, y_hat, alpha = 0.3 + (0.5*i/epochs))

print(theta)
# Out:
# [[3.17424274]
#  [3.66228245]]

# %% [markdown]
# ## Polinomial Regression

# %%
n = 100

x = 6 * np.random.rand(n, 1) - 3
y = 0.5 * x**2 + x + 2 *np.random.randn(n, 1)

plt.scatter(x, y)

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
poly_features = PolynomialFeatures(degree=2, include_bias=False)

x_poly = poly_features.fit_transform(x)
x_poly
# Out:
# array([[ 1.81387186e+00,  3.29013112e+00],
#        [ 2.39007791e+00,  5.71247240e+00],
#        [ 2.25873313e+00,  5.10187536e+00],
#        [-2.96499409e+00,  8.79118993e+00],
#        [ 7.65117313e-01,  5.85404502e-01],
#        [ 2.83645065e+00,  8.04545231e+00],
#        [ 2.40460711e+00,  5.78213533e+00],
#        [-7.32156840e-01,  5.36053639e-01],
#        [-1.64618532e+00,  2.70992611e+00],
#        [-1.14320720e+00,  1.30692270e+00],
#        [ 1.57929893e-01,  2.49418512e-02],
#        [ 1.30559094e+00,  1.70456772e+00],
#        [-4.86730026e-01,  2.36906118e-01],
#        [ 8.35194128e-01,  6.97549231e-01],
#        [-2.68293917e-01,  7.19816258e-02],
#        [-1.41497932e+00,  2.00216647e+00],
#        [ 1.33279115e+00,  1.77633225e+00],
#        [-5.39405766e-01,  2.90958580e-01],
#        [-7.77511211e-01,  6.04523684e-01],
#        [ 5.45389566e-01,  2.97449779e-01],
#        [ 2.94735758e+00,  8.68691673e+00],
#        [ 2.60426535e+00,  6.78219801e+00],
#        [-1.35398845e-01,  1.83328472e-02],
#        [ 2.38978185e+00,  5.71105730e+00],
#        [ 2.22777798e+00,  4.96299474e+00],
#        [-7.61738908e-01,  5.80246164e-01],
#        [ 2.44840161e+00,  5.99467045e+00],
#        [-2.79521834e+00,  7.81324559e+00],
#        [ 8.75209308e-01,  7.65991333e-01],
#        [-2.41929493e+00,  5.85298794e+00],
#        [-1.51530858e+00,  2.29616011e+00],
#        [-2.24768774e+00,  5.05210020e+00],
#        [ 3.67955056e-01,  1.35390924e-01],
#        [ 1.30981206e+00,  1.71560762e+00],
#        [ 1.86626067e+00,  3.48292887e+00],
#        [ 9.42910833e-01,  8.89080838e-01],
#        [ 1.12393729e+00,  1.26323503e+00],
#        [-2.73107150e+00,  7.45875155e+00],
#        [-8.46925121e-01,  7.17282161e-01],
#        [ 2.42856758e+00,  5.89794047e+00],
#        [-1.49619294e+00,  2.23859330e+00],
#        [-2.89764533e-01,  8.39634845e-02],
#        [-3.09896372e-03,  9.60357614e-06],
#        [-7.40461383e-01,  5.48283059e-01],
#        [ 1.74951937e-01,  3.06081802e-02],
#        [ 2.82197438e+00,  7.96353942e+00],
#        [-6.50336657e-01,  4.22937768e-01],
#        [ 2.62709326e+00,  6.90161901e+00],
#        [ 1.87760625e+00,  3.52540524e+00],
#        [-1.72803007e+00,  2.98608794e+00],
#        [ 2.60229491e+00,  6.77193882e+00],
#        [-2.60046686e+00,  6.76242788e+00],
#        [-4.67892160e-01,  2.18923073e-01],
#        [ 1.83087721e+00,  3.35211137e+00],
#        [-2.05719467e+00,  4.23204991e+00],
#        [ 4.48504556e-01,  2.01156337e-01],
#        [-2.61449222e+00,  6.83556957e+00],
#        [ 1.37302202e+00,  1.88518946e+00],
#        [-2.05415506e-02,  4.21955301e-04],
#        [-3.40419539e-01,  1.15885463e-01],
#        [ 1.54917742e+00,  2.39995069e+00],
#        [-9.52832487e-01,  9.07889747e-01],
#        [ 2.28480585e+00,  5.22033777e+00],
#        [ 2.63019423e-01,  6.91792169e-02],
#        [ 2.10005003e-01,  4.41021012e-02],
#        [-1.12095514e+00,  1.25654044e+00],
#        [-1.84160645e+00,  3.39151430e+00],
#        [ 1.11627322e+00,  1.24606591e+00],
#        [-9.60640551e-01,  9.22830268e-01],
#        [ 2.53751558e+00,  6.43898531e+00],
#        [ 2.25933033e+00,  5.10457355e+00],
#        [-2.86487254e+00,  8.20749468e+00],
#        [ 1.83450662e-01,  3.36541453e-02],
#        [ 1.21897546e+00,  1.48590117e+00],
#        [-9.72925948e-01,  9.46584900e-01],
#        [ 1.81579076e+00,  3.29709609e+00],
#        [-2.13843377e+00,  4.57289897e+00],
#        [ 2.58596969e+00,  6.68723922e+00],
#        [ 1.08092531e+00,  1.16839952e+00],
#        [ 2.10663163e+00,  4.43789681e+00],
#        [-2.16971190e+00,  4.70764972e+00],
#        [-2.69820594e+00,  7.28031531e+00],
#        [-6.52082906e-01,  4.25212116e-01],
#        [ 6.71182383e-02,  4.50485792e-03],
#        [ 7.03452804e-01,  4.94845847e-01],
#        [-2.17690401e-01,  4.73891106e-02],
#        [-1.62444160e+00,  2.63881050e+00],
#        [ 1.16545723e+00,  1.35829056e+00],
#        [ 2.92146081e+00,  8.53493328e+00],
#        [-6.31253820e-01,  3.98481386e-01],
#        [ 1.54619190e+00,  2.39070939e+00],
#        [ 2.01633576e+00,  4.06560991e+00],
#        [ 9.74580975e-01,  9.49808077e-01],
#        [-1.75688414e-01,  3.08664188e-02],
#        [-1.93669987e+00,  3.75080639e+00],
#        [-1.63621702e+00,  2.67720614e+00],
#        [-8.58586694e-01,  7.37171110e-01],
#        [-2.53396797e+00,  6.42099367e+00],
#        [ 8.10255422e-01,  6.56513848e-01],
#        [ 9.55322429e-01,  9.12640944e-01]])

# %%
from sklearn.linear_model import LinearRegression

# %%
lin_reg = LinearRegression()

lin_reg.fit(x_poly, y)
# Out:
# LinearRegression()

# %%
lin_reg.coef_
# Out:
# array([[1.17013415, 0.41744583]])

# %%
plt.scatter(x, y)
plt.scatter(x, lin_reg.predict(x_poly))

# %% [markdown]
# ## Ridge Regression

# %%
x = np.random.rand(100, 1) -3
y = np.random.randn(100, 1)

# %%
plt.scatter(x, y)

# %%
from sklearn.linear_model import Ridge

# %%
fig, ax = plt.subplots(figsize = (25, 8))
plt.scatter(x, y)

for alpha in [0, 1e-5, 1]:
    poly_features = PolynomialFeatures(degree=10, include_bias=False)
    x_poly =  poly_features.fit_transform(x)

    x_seq = np.linspace(x.min(),x.max(), 300).reshape(-1, 1)

    ridge_reg = Ridge(alpha = alpha, solver="cholesky")
    ridge_reg.fit(x_poly, y)

    x_seq_transf = poly_features.fit_transform(x_seq)

    plt.plot(x_seq, ridge_reg.predict(x_seq_transf), label=alpha)

ax.legend()

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn import datasets

iris_data = datasets.load_iris()

# %%
iris_data['feature_names']
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
iris_data['data']
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3. , 1.4, 0.1],
#        [4.3, 3. , 1.1, 0.1],
#        [5.8, 4. , 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1. , 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5. , 3. , 1.6, 0.2],
#        [5. , 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
#        [5.2, 4.1, 1.5, 0.1],
#        [5.5, 4.2, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.2],
#        [5. , 3.2, 1.2, 0.2],
#        [5.5, 3.5, 1.3, 0.2],
#        [4.9, 3.6, 1.4, 0.1],
#        [4.4, 3. , 1.3, 0.2],
#        [5.1, 3.4, 1.5, 0.2],
#        [5. , 3.5, 1.3, 0.3],
#        [4.5, 2.3, 1.3, 0.3],
#        [4.4, 3.2, 1.3, 0.2],
#        [5. , 3.5, 1.6, 0.6],
#        [5.1, 3.8, 1.9, 0.4],
#        [4.8, 3. , 1.4, 0.3],
#        [5.1, 3.8, 1.6, 0.2],
#        [4.6, 3.2, 1.4, 0.2],
#        [5.3, 3.7, 1.5, 0.2],
#        [5. , 3.3, 1.4, 0.2],
#        [7. , 3.2, 4.7, 1.4],
#        [6.4, 3.2, 4.5, 1.5],
#        [6.9, 3.1, 4.9, 1.5],
#        [5.5, 2.3, 4. , 1.3],
#        [6.5, 2.8, 4.6, 1.5],
#        [5.7, 2.8, 4.5, 1.3],
#        [6.3, 3.3, 4.7, 1.6],
#        [4.9, 2.4, 3.3, 1. ],
#        [6.6, 2.9, 4.6, 1.3],
#        [5.2, 2.7, 3.9, 1.4],
#        [5. , 2. , 3.5, 1. ],
#        [5.9, 3. , 4.2, 1.5],
#        [6. , 2.2, 4. , 1. ],
#        [6.1, 2.9, 4.7, 1.4],
#        [5.6, 2.9, 3.6, 1.3],
#        [6.7, 3.1, 4.4, 1.4],
#        [5.6, 3. , 4.5, 1.5],
#        [5.8, 2.7, 4.1, 1. ],
#        [6.2, 2.2, 4.5, 1.5],
#        [5.6, 2.5, 3.9, 1.1],
#        [5.9, 3.2, 4.8, 1.8],
#        [6.1, 2.8, 4. , 1.3],
#        [6.3, 2.5, 4.9, 1.5],
#        [6.1, 2.8, 4.7, 1.2],
#        [6.4, 2.9, 4.3, 1.3],
#        [6.6, 3. , 4.4, 1.4],
#        [6.8, 2.8, 4.8, 1.4],
#        [6.7, 3. , 5. , 1.7],
#        [6. , 2.9, 4.5, 1.5],
#        [5.7, 2.6, 3.5, 1. ],
#        [5.5, 2.4, 3.8, 1.1],
#        [5.5, 2.4, 3.7, 1. ],
#        [5.8, 2.7, 3.9, 1.2],
#        [6. , 2.7, 5.1, 1.6],
#        [5.4, 3. , 4.5, 1.5],
#        [6. , 3.4, 4.5, 1.6],
#        [6.7, 3.1, 4.7, 1.5],
#        [6.3, 2.3, 4.4, 1.3],
#        [5.6, 3. , 4.1, 1.3],
#        [5.5, 2.5, 4. , 1.3],
#        [5.5, 2.6, 4.4, 1.2],
#        [6.1, 3. , 4.6, 1.4],
#        [5.8, 2.6, 4. , 1.2],
#        [5. , 2.3, 3.3, 1. ],
#        [5.6, 2.7, 4.2, 1.3],
#        [5.7, 3. , 4.2, 1.2],
#        [5.7, 2.9, 4.2, 1.3],
#        [6.2, 2.9, 4.3, 1.3],
#        [5.1, 2.5, 3. , 1.1],
#        [5.7, 2.8, 4.1, 1.3],
#        [6.3, 3.3, 6. , 2.5],
#        [5.8, 2.7, 5.1, 1.9],
#        [7.1, 3. , 5.9, 2.1],
#        [6.3, 2.9, 5.6, 1.8],
#        [6.5, 3. , 5.8, 2.2],
#        [7.6, 3. , 6.6, 2.1],
#        [4.9, 2.5, 4.5, 1.7],
#        [7.3, 2.9, 6.3, 1.8],
#        [6.7, 2.5, 5.8, 1.8],
#        [7.2, 3.6, 6.1, 2.5],
#        [6.5, 3.2, 5.1, 2. ],
#        [6.4, 2.7, 5.3, 1.9],
#        [6.8, 3. , 5.5, 2.1],
#        [5.7, 2.5, 5. , 2. ],
#        [5.8, 2.8, 5.1, 2.4],
#        [6.4, 3.2, 5.3, 2.3],
#        [6.5, 3. , 5.5, 1.8],
#        [7.7, 3.8, 6.7, 2.2],
#        [7.7, 2.6, 6.9, 2.3],
#        [6. , 2.2, 5. , 1.5],
#        [6.9, 3.2, 5.7, 2.3],
#        [5.6, 2.8, 4.9, 2. ],
#        [7.7, 2.8, 6.7, 2. ],
#        [6.3, 2.7, 4.9, 1.8],
#        [6.7, 3.3, 5.7, 2.1],
#        [7.2, 3.2, 6. , 1.8],
#        [6.2, 2.8, 4.8, 1.8],
#        [6.1, 3. , 4.9, 1.8],
#        [6.4, 2.8, 5.6, 2.1],
#        [7.2, 3. , 5.8, 1.6],
#        [7.4, 2.8, 6.1, 1.9],
#        [7.9, 3.8, 6.4, 2. ],
#        [6.4, 2.8, 5.6, 2.2],
#        [6.3, 2.8, 5.1, 1.5],
#        [6.1, 2.6, 5.6, 1.4],
#        [7.7, 3. , 6.1, 2.3],
#        [6.3, 3.4, 5.6, 2.4],
#        [6.4, 3.1, 5.5, 1.8],
#        [6. , 3. , 4.8, 1.8],
#        [6.9, 3.1, 5.4, 2.1],
#        [6.7, 3.1, 5.6, 2.4],
#        [6.9, 3.1, 5.1, 2.3],
#        [5.8, 2.7, 5.1, 1.9],
#        [6.8, 3.2, 5.9, 2.3],
#        [6.7, 3.3, 5.7, 2.5],
#        [6.7, 3. , 5.2, 2.3],
#        [6.3, 2.5, 5. , 1.9],
#        [6.5, 3. , 5.2, 2. ],
#        [6.2, 3.4, 5.4, 2.3],
#        [5.9, 3. , 5.1, 1.8]])

# %%
x = iris_data['data'][:, 3:]
y = (iris_data['target']==2).astype(np.int64)

# %%
from sklearn.linear_model import LogisticRegression

log_reg = LogisticRegression()

log_reg.fit(x, y)
# Out:
# LogisticRegression()

# %%
fig, ax = plt.subplots(figsize=(25, 8))

x_new = np.linspace(0, 3, 1000).reshape(-1, 1)
y_prob= log_reg.predict_proba(x_new)
plt.plot(x_new, y_prob[:, 1])

# %% [markdown]
# ## SoftMax Regression

# %%
x = iris_data["data"][:, (2, 3)]
y = iris_data["target"]

# %%
softmax_reg = LogisticRegression(multi_class="multinomial")
softmax_reg.fit(x, y)
# Out:
# c:\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# LogisticRegression(multi_class='multinomial')

# %%
softmax_reg.predict_proba([[5, 2]])
# Out:
# array([[2.43199208e-04, 2.14948752e-01, 7.84808048e-01]])

# %%
# Plot the decision boundary. For that, we will assign a color to each
# point in the mesh [x_min, x_max]x[y_min, y_max].
x_min, x_max = x[:, 0].min() - 0.5, x[:, 0].max() + 0.5
y_min, y_max = x[:, 1].min() - 0.5, x[:, 1].max() + 0.5
h = 0.02  # step size in the mesh
xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
Z = softmax_reg.predict(np.c_[xx.ravel(), yy.ravel()])

# Put the result into a color plot
Z = Z.reshape(xx.shape)
plt.figure(1, figsize=(25, 9))
plt.pcolormesh(xx, yy, Z, cmap=plt.cm.Paired)

# Plot also the training points
plt.scatter(x[:, 0], x[:, 1], c=y, edgecolors="k", cmap=plt.cm.Paired)
plt.xlabel("Sepal length")
plt.ylabel("Sepal width")

plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
plt.xticks(())
plt.yticks(())

plt.show()
